# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/colabIP/Images/milkdrop.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
gBin = np.zeros((gimg.shape[0], gimg.shape[1]), dtype = np.ubyte)

threshold = 150

for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    if(gimg[h,w]> threshold):
      gBin[h,w] = 255

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3), np.uint8)
erodeimg = cv2.erode(gBin, kernel, iterations=5)
cv2_imshow(erodeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3), np.uint8)
dilateimg = cv2.dilate(gBin, kernel, iterations=5)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/colabIP/Images/scanimages.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg)
# Out:
# (124, 400)
# <PIL.Image.Image image mode=L size=400x124>

# %%
kernel = np.ones((3,1), np.uint8)
dilateimg = cv2.dilate(gimg, kernel, iterations=1)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=400x124>

# %%
kernel = np.ones((3,1), np.uint8)
erodeimg = cv2.erode(dilateimg, kernel, iterations=1)
cv2_imshow(erodeimg)
# Out:
# <PIL.Image.Image image mode=L size=400x124>

# %%
kernel = np.ones((4,1), np.uint8)
erodeimg = cv2.erode(dilateimg, kernel, iterations=1)
cv2_imshow(erodeimg)
# Out:
# <PIL.Image.Image image mode=L size=400x124>

# %%
img = cv2.imread('/content/gdrive/My Drive/colabIP/Images/fce(salt_pepper noise).bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,1), np.uint8)
dilateimg = cv2.dilate(gimg, kernel, iterations=1)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,1), np.uint8)
erodeimg = cv2.erode(dilateimg, kernel, iterations=2)
cv2_imshow(erodeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
